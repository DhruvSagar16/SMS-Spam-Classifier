# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('spam.csv', encoding="latin1")

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 1013   ham  Just buy a pizza. Meat lovers or supreme. U ge...        NaN
# 3949   ham  I got to video tape pple type in message lor. ...        NaN
# 5197   ham  I like cheap! But iÛ÷m happy to splash out on...        NaN
# 1474   ham  Friendship is not a game to play, It is not a ...        NaN
# 1829  spam  Hottest pics straight to your phone!! See me g...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 1013        NaN        NaN
# 3949        NaN        NaN
# 5197        NaN        NaN
# 1474        NaN        NaN
# 1829        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# ## 1. Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# Drop last 3 cols
df.drop(columns = ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 3459  ham  I am back. Bit long cos of accident on a30. Ha...
# 326   ham                    Hi da:)how is the todays class?
# 3142  ham  Boy; I love u Grl: Hogolo Boy: gold chain kods...
# 4205  ham                             Get the door, I'm here
# 607   ham  what I meant to say is cant wait to see u agai...

# %%
# Renaming cols 
df.rename(columns={ 'v1': 'target', 'v2' : 'text'}, inplace= True)
df.sample(5)
# Out:
#      target                                               text
# 2167    ham                   Yes.he have good crickiting mind
# 3312    ham  Huh... Hyde park not in mel ah, opps, got conf...
# 3785    ham                                     Wat r u doing?
# 413     ham                           Bring home some Wendy =D
# 4921    ham  Hi Dear Call me its urgnt. I don't know whats ...

# %%
# Converting spam = 1 and ham = 0
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head(5)
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# Checking missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# Checking for duplicate values
print(df.duplicated().sum())
# Out:
# 403

# %%
# Removing duplicate values
df = df.drop_duplicates(keep = 'first')

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ## 2. EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt 
plt.pie(df['target'].value_counts(), labels = ['ham', 'spam'], autopct="%0.2f")
plt.show()

# %% [markdown]
# #### Data is imbalanced as there is high number of ham and low number of spam (nltk = natural language toolkit)

# %%
import nltk

# %%
# !pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sagar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sagar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['num_characters'] =  df['text'].apply(len)

# %%
df.head(5)
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
# Count the Num of words
df['num_words'] = df['text'].apply(lambda x : len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
# Count the Number of sentences (sentence ke basis par sms ko break(tokenize) kar rahe ho.)
df['num_sentences'] = df['text'].apply(lambda x : len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# Ham messages
df[df['target'] == 0][['num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# Spam messages
df[df['target'] == 1][['num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
# Showing that spam has more characters where as ham has less number of characters.
plt.figure(figsize=(12, 6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'], color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
# Showing that spam has more words and sentences where as ham has less number of words and sentences.
plt.figure(figsize=(12, 6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'], color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df, hue='target')

# %% [markdown]
# ### There is outliers in the dataset which can ruin the analysis

# %%
# Calculate the Pearson coefficient
numeric_df = df.select_dtypes(include=['int64', 'float64'])
sns.heatmap(numeric_df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Data Preprocessing
#     a. Lower case
#     b. Tokenization
#     c. Removing special characters
#     d. Removing stop words and punctuation
#     e. Stemming

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sagar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# These words dont add meaning to the sentence they are just there for sentence formation
# d. Removing stop words and punctuation
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
# These are the punctuation marks
# d. Removing stop words and punctuation
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# e. Stemming
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
def transform_text(text):
    text = text.lower()   # a. Lower case
    text = nltk.word_tokenize(text) # b. Tokenization

    # c. Removing special characters
    y = []
    for i in text:
        if i.isalnum():    #isalnum() = alphanumeric
            y.append(i)

    # d. Removing stop words and punctuation
    text = y[:]
    y.clear()

    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    # e. Stemming
    text = y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))
            
    return y

# %%
# Eg for the above function
transform_text("I loved the YT videos on Machine Learning. How about you?")
# Out:
# ['love', 'yt', 'video', 'machin', 'learn']

# %%
df['transformed_text'] =  df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  [go, jurong, point, crazi, avail, bugi, n, gre...
# 1          8              2                       [ok, lar, joke, wif, u, oni]
# 2         37              2  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3         13              1      [u, dun, say, earli, hor, u, c, alreadi, say]
# 4         15              1       [nah, think, goe, usf, live, around, though]

# %%
# !pip install wordcloud
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Creating a WordCloud ie. WordCloud = it shows words which are important in a bigger size.
from wordcloud import WordCloud
wc = WordCloud(width=500, height=500, min_font_size = 10, background_color='white')

# %%
spam_wc = df[df['target'] == 1]['transformed_text'].astype(str)
wc.generate(" ".join(spam_wc))

# %%
plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.show()

# %%
ham_wc = df[df['target'] == 0]['transformed_text'].astype(str)
wc_ham = wc.generate(" ".join(ham_wc))

# %%
plt.figure(figsize=(10,6))
plt.imshow(wc_ham, interpolation='bilinear')
plt.axis("off")
plt.title("Ham WordCloud")
plt.show()

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  [go, jurong, point, crazi, avail, bugi, n, gre...
# 1          8              2                       [ok, lar, joke, wif, u, oni]
# 2         37              2  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3         13              1      [u, dun, say, earli, hor, u, c, alreadi, say]
# 4         15              1       [nah, think, goe, usf, live, around, though]

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'] \
               .fillna("") \
               .apply(lambda x: " ".join(x) if isinstance(x, list) else str(x)) \
               .tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
# This will give the 30 most occuring words for spam messages.
from collections import Counter
spam_top_30 = pd.DataFrame(Counter(spam_corpus).most_common(30))
spam_top_30.columns = ['word', 'count']

plt.figure(figsize=(10,6))
sns.barplot(x='word', y='count', data=spam_top_30)
plt.xticks(rotation=90)
plt.show()

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'] \
               .fillna("") \
               .apply(lambda x: " ".join(x) if isinstance(x, list) else str(x)) \
               .tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
# This will give the 30 most occuring words for ham messages.
from collections import Counter
ham_top_30 = pd.DataFrame(Counter(ham_corpus).most_common(30))
ham_top_30.columns = ['word', 'count']

plt.figure(figsize=(10,6))
sns.barplot(x='word', y='count', data=ham_top_30)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 4. Model Building

# %% [markdown]
# ### We will be using Naive Bayes algorithm because it give good performance on Textual Data.

# %%
# We need to convert text data into numerical type or we can say that convert text into vectors. 
# Methods To vectorize:
# 1. Bag of words, 2. TF - IDF, 3. word to word

# %%
# Text Vectorization
# 1. Using Bag of words
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  [go, jurong, point, crazi, avail, bugi, n, gre...
# 1          8              2                       [ok, lar, joke, wif, u, oni]
# 2         37              2  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3         13              1      [u, dun, say, earli, hor, u, c, alreadi, say]
# 4         15              1       [nah, think, goe, usf, live, around, though]

# %%
# Using Bag of words & TF IDF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features= 3000)

# %%
# Converting sparse array into dense array
df['text_for_vectorizer'] = df['transformed_text'].apply(
    lambda x: " ".join(x) if isinstance(x, list) else str(x)
)

# %%
X = tfidf.fit_transform(df['text_for_vectorizer']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5169,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
#  (here 3 naive_bayes algos are just importing nothing else)
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# %%
# Teeno ka bas object bana raha hu
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
# Performing very bad
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
print(precision_score(y_test, y_pred1))
# Out:
# 0.874274661508704
# [[790 106]
#  [ 24 114]]
# 0.5181818181818182

# %%
# Hume precision_score jyada se jyada chaiye
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
print(precision_score(y_test, y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
print(precision_score(y_test, y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %% [markdown]
# ### We are choosing tfidf with mnb

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9758220502901354, 0.9747899159663865)

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9758220502901354
# Precision -  0.9747899159663865
# For  KN
# Accuracy -  0.9052224371373307
# Precision -  1.0
# For  NB
# Accuracy -  0.9709864603481625
# Precision -  1.0
# For  DT
# Accuracy -  0.9332688588007737
# Precision -  0.8415841584158416
# For  LR
# Accuracy -  0.9555125725338491
# Precision -  0.96
# For  RF
# Accuracy -  0.9738878143133463
# Precision -  0.9826086956521739
# For  AdaBoost
# Accuracy -  0.9216634429400387
# Precision -  0.8202247191011236
# For  BgC
# Accuracy -  0.9584139264990329
# Precision -  0.8682170542635659
# For  ETC
# Accuracy -  0.9748549323017408
# Precision -  0.9745762711864406
# For  GBDT
# Accuracy -  0.9506769825918762
# Precision -  0.9306930693069307
# For  xgb
# Accuracy -  0.9680851063829787
# Precision -  0.9487179487179487

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 1         KN  0.905222   1.000000
# 2         NB  0.970986   1.000000
# 5         RF  0.973888   0.982609
# 0        SVC  0.975822   0.974790
# 8        ETC  0.974855   0.974576
# 4         LR  0.955513   0.960000
# 10       xgb  0.968085   0.948718
# 9       GBDT  0.950677   0.930693
# 7        BgC  0.958414   0.868217
# 3         DT  0.933269   0.841584
# 6   AdaBoost  0.921663   0.820225

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")

# %%
performance_df1
# Out:
#    Algorithm   variable     value
# 0         KN   Accuracy  0.905222
# 1         NB   Accuracy  0.970986
# 2         RF   Accuracy  0.973888
# 3        SVC   Accuracy  0.975822
# 4        ETC   Accuracy  0.974855
# 5         LR   Accuracy  0.955513
# 6        xgb   Accuracy  0.968085
# 7       GBDT   Accuracy  0.950677
# 8        BgC   Accuracy  0.958414
# 9         DT   Accuracy  0.933269
# 10  AdaBoost   Accuracy  0.921663
# 11        KN  Precision  1.000000
# 12        NB  Precision  1.000000
# 13        RF  Precision  0.982609
# 14       SVC  Precision  0.974790
# 15       ETC  Precision  0.974576
# 16        LR  Precision  0.960000
# 17       xgb  Precision  0.948718
# 18      GBDT  Precision  0.930693
# 19       BgC  Precision  0.868217
# 20        DT  Precision  0.841584
# 21  AdaBoost  Precision  0.820225

# %%
sns.catplot(x = 'Algorithm', y='value', 
               hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### model improve
# ### 1. Change the max_features parameter of TfIdf

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_scaling':accuracy_scores,'Precision_scaling':precision_scores}).sort_values('Precision_scaling',ascending=False)

# %%
new_df = performance_df.merge(temp_df,on='Algorithm')

# %%
new_df_scaled = new_df.merge(temp_df,on='Algorithm')

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_num_chars':accuracy_scores,'Precision_num_chars':precision_scores}).sort_values('Precision_num_chars',ascending=False)

# %%
new_df_scaled.merge(temp_df,on='Algorithm')
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_scaling_x  Precision_scaling_x  \
# 0         KN  0.905222   1.000000            0.905222             1.000000
# 1         NB  0.970986   1.000000            0.970986             1.000000
# 2         RF  0.973888   0.982609            0.973888             0.982609
# 3        SVC  0.975822   0.974790            0.975822             0.974790
# 4        ETC  0.974855   0.974576            0.974855             0.974576
# 5         LR  0.955513   0.960000            0.955513             0.960000
# 6        xgb  0.968085   0.948718            0.968085             0.948718
# 7       GBDT  0.950677   0.930693            0.950677             0.930693
# 8        BgC  0.958414   0.868217            0.958414             0.868217
# 9         DT  0.933269   0.841584            0.933269             0.841584
# 10  AdaBoost  0.921663   0.820225            0.921663             0.820225
#
#     Accuracy_scaling_y  Precision_scaling_y  Accuracy_num_chars  \
# ...

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
